# %% [markdown]
# # Mushroom Classification

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from tensorflow import keras
from functools import partial

# %%
# Loading the data

df = pd.read_csv('mushrooms.csv')
df.head()
df.shape
# Out:
# (8124, 23)

# %%
# Data preprocessing

df['class'] = df['class'].map({'p': 1, 'e': 0})
class_by_population = df.groupby(['population'])['class'].value_counts(normalize=True).unstack()
class_by_population = class_by_population.sort_values(by=1, ascending=False)
class_by_habitat = df.groupby(['habitat'])['class'].value_counts(normalize=True).unstack()
class_by_habitat = class_by_habitat.sort_values(by=1, ascending=False)

y = df.loc[:,'class'].values
X = df.drop(['class'], axis=1)

encoder = OneHotEncoder(drop='first')
X = encoder.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=True)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, shuffle=True)

# %%
# Model Creation

# MyDense = partial(keras.layers.Dense, activation="selu", kernel_initializer="lecun_normal")
MyDense = partial(keras.layers.Dense, activation="relu", kernel_initializer="he_normal")

input_layer = keras.layers.Input(shape=X_train.shape[1:])

# hidden1 = MyDense(20)(input_layer)
# hidden2 = MyDense(10)(hidden1)
hidden1 = MyDense(10)(input_layer)
hidden2 = MyDense(5)(hidden1)

# dropout = keras.layers.Dropout(rate=0.2)(hidden2)
dropout = keras.layers.Dropout(rate=0.3)(hidden2)

output = MyDense(1, activation="sigmoid", kernel_initializer="uniform")(dropout)

model = keras.models.Model(inputs=[input_layer], outputs=[output])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
lr_scheduler_cb = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
optimizer = keras.optimizers.Nadam(lr=0.001, beta_1=0.9, beta_2=0.999)

model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Nadam.

# %%
# Model Training

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

model.save('model.h5')
# Out:
# Epoch 1/50
# 184/184 [==============================] - 2s 2ms/step - loss: 0.4742 - accuracy: 0.8236 - val_loss: 0.1662 - val_accuracy: 0.9624
# Epoch 2/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.1429 - accuracy: 0.9521 - val_loss: 0.0564 - val_accuracy: 0.9865
# Epoch 3/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0857 - accuracy: 0.9732 - val_loss: 0.0271 - val_accuracy: 0.9942
# Epoch 4/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9809 - val_loss: 0.0157 - val_accuracy: 0.9981
# Epoch 5/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9831 - val_loss: 0.0088 - val_accuracy: 0.9981
# Epoch 6/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9830 - val_loss: 0.0058 - val_accuracy: 0.9990
# Epoch 7/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 8/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9860 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 9/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0426 - accuracy: 0.9833 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 10/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0425 - accuracy: 0.9825 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 11/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 0.9860 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 12/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9867 - val_loss: 8.0708e-04 - val_accuracy: 1.0000
# Epoch 13/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9869 - val_loss: 6.0895e-04 - val_accuracy: 1.0000
# Epoch 14/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 6.2945e-04 - val_accuracy: 1.0000
# Epoch 15/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9850 - val_loss: 7.6179e-04 - val_accuracy: 1.0000
# Epoch 16/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9825 - val_loss: 3.3571e-04 - val_accuracy: 1.0000
# Epoch 17/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0329 - accuracy: 0.9879 - val_loss: 3.3646e-04 - val_accuracy: 1.0000
# Epoch 18/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9869 - val_loss: 2.7824e-04 - val_accuracy: 1.0000
# Epoch 19/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9908 - val_loss: 1.7192e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9853 - val_loss: 1.4944e-04 - val_accuracy: 1.0000
# Epoch 21/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9853 - val_loss: 1.3769e-04 - val_accuracy: 1.0000
# Epoch 22/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 0.9865 - val_loss: 1.0011e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.9859 - val_loss: 7.9630e-05 - val_accuracy: 1.0000
# Epoch 24/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9865 - val_loss: 6.4617e-05 - val_accuracy: 1.0000
# Epoch 25/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 0.9857 - val_loss: 5.6822e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9860 - val_loss: 8.7180e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9896 - val_loss: 4.0208e-05 - val_accuracy: 1.0000
# Epoch 28/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9884 - val_loss: 3.2654e-05 - val_accuracy: 1.0000
# Epoch 29/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9871 - val_loss: 2.5127e-05 - val_accuracy: 1.0000
# Epoch 30/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 0.9852 - val_loss: 4.3087e-05 - val_accuracy: 1.0000
# Epoch 31/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9864 - val_loss: 3.2285e-05 - val_accuracy: 1.0000
# Epoch 32/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9889 - val_loss: 7.5640e-05 - val_accuracy: 1.0000
# Epoch 33/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 0.9864 - val_loss: 4.2090e-05 - val_accuracy: 1.0000
# Epoch 34/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9871 - val_loss: 1.3771e-05 - val_accuracy: 1.0000
# Epoch 35/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 0.9871 - val_loss: 1.3562e-05 - val_accuracy: 1.0000
# Epoch 36/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 0.9884 - val_loss: 9.1375e-06 - val_accuracy: 1.0000
# Epoch 37/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9864 - val_loss: 1.6324e-05 - val_accuracy: 1.0000
# Epoch 38/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9864 - val_loss: 1.4685e-05 - val_accuracy: 1.0000
# Epoch 39/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9886 - val_loss: 1.2155e-05 - val_accuracy: 1.0000
# Epoch 40/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9853 - val_loss: 9.3390e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0333 - accuracy: 0.9862 - val_loss: 9.6517e-06 - val_accuracy: 1.0000
# Epoch 42/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9898 - val_loss: 5.2419e-06 - val_accuracy: 1.0000
# Epoch 43/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9881 - val_loss: 4.9394e-06 - val_accuracy: 1.0000
# Epoch 44/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9855 - val_loss: 4.8339e-06 - val_accuracy: 1.0000
# Epoch 45/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9888 - val_loss: 9.0582e-06 - val_accuracy: 1.0000
# Epoch 46/50
# 184/184 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 0.9872 - val_loss: 6.5759e-06 - val_accuracy: 1.0000
# Epoch 47/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9862 - val_loss: 4.4686e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9884 - val_loss: 5.8796e-06 - val_accuracy: 1.0000
# Epoch 49/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9871 - val_loss: 2.9599e-06 - val_accuracy: 1.0000
# Epoch 50/50
# 184/184 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9882 - val_loss: 2.6608e-06 - val_accuracy: 1.0000

# %%
# Model Evaluate

val_loss, val_acc = model.evaluate(X_test, y_test)

print("Loss: ",val_loss)
print("Accuracy: ",val_acc*100, "%")
# Out:
# 39/39 [==============================] - 0s 1ms/step - loss: 1.4229e-06 - accuracy: 1.0000
# Loss:  1.4228721738618333e-06
# Accuracy:  100.0 %
